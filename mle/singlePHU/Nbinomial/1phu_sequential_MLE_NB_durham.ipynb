# %% [markdown]
# ## Sequntial maximum likelihood estimation of infection rate parameters of a single PHU using negative Binomial

# %%
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

from scipy.optimize import minimize

##### CHANGE HERE #############
### Use the time up to which you need to estimate the parameters of sigmoid
dt = 0.1
tstart = 0
tlim = 210
t = np.arange(tstart, tlim, 1)


### keep it always starting at 0
tmoh = np.arange(0, tlim, dt)

ndiv = 1/dt


##### CHANGE HERE #############

###### If you have your own data, load it here #######
### Currently loaded infection data from MOH, for April 2020 to March 2021

PHU_path = '/Users/sudhipv/documents/coupled_compartment/PHU_Data/'
datapath = '/Users/sudhipv/documents/coupled_compartment/data/'
figpath = '/Users/sudhipv/documents/coupled_compartment/figs/mle'
Data = np.zeros([365,4])

files = os.listdir(PHU_path)

target_file1 = f'{PHU_path}/30-Toronto.csv'
target_file2 = f'{PHU_path}/34-York.csv'
target_file3 = f'{PHU_path}/04-Durham.csv'
target_file4 = f'{PHU_path}/22-PeelRegion.csv'

Data[:,0] = np.genfromtxt(target_file1, delimiter=',')
Data[:,1] = np.genfromtxt(target_file2, delimiter=',')
Data[:,2] = np.genfromtxt(target_file3, delimiter=',')
Data[:,3] = np.genfromtxt(target_file4, delimiter=',')


population_by_phu = np.genfromtxt(f'{PHU_path}/population_by_phu.csv', delimiter=',')


N_city = 1
# Preallocate compartments
S = np.zeros((len(tmoh),N_city))
E = np.zeros((len(tmoh),N_city))
I = np.zeros((len(tmoh),N_city))
R = np.zeros((len(tmoh),N_city))
D = np.zeros((len(tmoh),N_city))
N = np.zeros((len(tmoh),N_city))

I_synthetic = np.zeros((len(t),N_city))

##### CHANGE HERE #############
## Observed data

### MOH data - No true solution
I_synthetic[:,0] =  Data[tstart:tlim,2]

### Synthetic data - true solution
# file = np.loadtxt(f'{datapath}/toronto_synthetic_data_r100_initial.csv')
# I_synthetic[:,0] = file[tstart:tlim]

##############################

L_Force = np.zeros((len(tmoh),N_city))

##### CHANGE HERE #############
total = population_by_phu[3,1]
##### CHANGE HERE #############


# Model parameters - Taken from Southern Ontario - COVID MBE paper
gamma_e = 1/15
gamma_i = 1/5
gamma_r = 1/11
gamma_d = 1/750

beta_e = np.zeros((len(tmoh),N_city)) 
beta_i = np.zeros((len(tmoh),N_city))

beta_calibrated = np.zeros((len(tmoh),N_city))


print("initial infected",I[0,0])

print("total population",total)


#### PEEL - 234 , 1451022

#### Toronto - 430 , 2794356

### York - 212, 1173334

### Durham - 94   - 696992


mpl.rcParams.update({'font.size':14})
# Out:
# initial infected 0.0
# total population 696992.0

# %%
################### Durham ##########################################################
nparam = 10
param = np.ones(nparam)
##### CHANGE HERE ############
### Use the parameters which needs to be included in the sum of sigmoids model for MLE estimation
### When doing sequential calibration, include all the parameters until that time which are already calibrated. 


##### CHANGE HERE #############
E[0,0] = 96
I[0,0] = 96
##############################
R[0,0] = 0
D[0,0] = 0
N[0,0] = total
S[0,0] = N[0,0] - E[0,0] - I[0,0] - R[0,0] - D[0,0]

################### Durham ##########################################################


# Original
a0 =   0.14
a1 =  -0.115
t1 =   20
a2 =   0.06
t2 =  35
a3 =   -0.05
t3 = 65
a4 =  0.035
t4 = 90
a5 =  0.06
t5 = 140
a6 =  -0.075
t6 = 180
a7 =  0.06
t7 = 190
a8 =  -0.025
t8 = 250

### Initial Guesses

a0 = 0.1
a1 = -0.09
a2 = 0.04
a3 = -0.02
a4 = 0.01
a5 = 0.04
a6 = -0.01
a7 = 0.04




### CHANGE HERE 
beta_i[:,0] = a0  + a1/(1 + np.exp((t1-tmoh))) \
+ a2/(1 + np.exp((t2-tmoh))) \
+ a3/(1 + np.exp((t3-tmoh))) \
+ a4/(1 + np.exp((t4-tmoh))) \
+ a5/(1 + np.exp((t5-tmoh))) \
+ a6/(1 + np.exp((t6-tmoh))) \
+ a7/(1 + np.exp((t7-tmoh))) \
# + a8/(1 + np.exp((t8-tmoh)))

beta_e[:,0] = beta_i[:,0]



#### DEFINE THE PARAMETERS TO BE ESTIMATED 

### CHANGE HERE 
param = np.array([a0,a1,a2,a3,a4,a5,a6,a7,E[0,0],I[0,0]])

# %%
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]

  if( kk%ndiv == 0):
      idxmoh = int(kk/ndiv)



fig1, ax1 = plt.subplots(figsize=(6, 4))
ax1.set_xlim([0,tlim])
ax1.set_xlabel('Time (days)')
ax1.set_ylabel('Infected cases') 
ax1.grid()
plt.plot(t, I_synthetic[:,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh, I[:,0], '-',linewidth=2, label='Initial guess model output')
ax1.legend(loc='best')
# plt.savefig('./figs/noisy_data.pdf',  bbox_inches='tight')
plt.show()



fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Sum of sigmoid model')
ax1.legend(loc='best')
# plt.savefig('./figs/beta.pdf',  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Applying scipy optimization library

# %%
#### CHANGE HERE 
### decrease p to reduce r and thus dispersion, increase p to get more dispersion
r = 100 ### Number of success


def loglikelihood(param):
      
    idxmoh = 1
    idxdata= 0

    loglik = 0

    FoI = np.zeros((len(tmoh),1))

    E[0,0] = param[8]

    I[0,0] = param[9]

############### CHANGE HERE #################
###### Update the model of beta to include the parameter which needs to be estimated along with the known paramters until that time
    beta_i[:,0] = param[0] + param[1]/(1 + np.exp((t1-tmoh))) \
    + param[2]/(1 + np.exp((t2-tmoh)))  \
    + param[3]/(1 + np.exp((t3-tmoh))) \
    + param[4]/(1 + np.exp((t4-tmoh))) \
    + param[5]/(1 + np.exp((t5-tmoh))) \
    + param[6]/(1 + np.exp((t6-tmoh))) \
    + param[7]/(1 + np.exp((t7-tmoh))) \
    # + param[8]/(1 + np.exp((t8-tmoh)))
    

    beta_e[:,0] = beta_i[:,0]   


######### For adding the initial condition value to likelihood
    logNfac = 0.0

    if int(I_synthetic[0]) != 0:
        logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[0]),1)+1)) #log factorial

    # r = (p*I[kk,0])/(1-p)
    p = r /(I[0,0] + r)
    loglik = loglik + (math.lgamma(I_synthetic[0]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[0]*np.log(1-p))

    for kk in range(1,len(tmoh)):

            FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

            S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
            E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
            I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
            R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
            D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
            N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


            ## For collecting the model output only at data points
            if( kk%ndiv == 0 ):
                idxmoh = int(kk/ndiv)


                if(tstart != 0):
                    if(idxmoh >= tstart and idxmoh < tlim):
                         
                        logNfac = 0.0

                        if int(I_synthetic[idxdata]) != 0:
                            logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxdata]),1)+1)) #log factorial

                        # r = (p*I[kk,0])/(1-p)
                        p = r /(I[kk,0] + r)
                        loglik = loglik + (math.lgamma(I_synthetic[idxdata]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxdata]*np.log(1-p))
                        idxdata+=1
            
                else:

                    logNfac = 0.0

                    if int(I_synthetic[idxmoh]) != 0:
                        logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxmoh]),1)+1)) #log factorial

                    # r = (p*I[kk,0])/(1-p)
                    p = r /(I[kk,0] + r)
                    loglik = loglik + (math.lgamma(I_synthetic[idxmoh]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxmoh]*np.log(1-p))

    
    return -loglik



options_bfgs = {
    'gtol': 1e-12,  # Gradient norm tolerance for convergence
    'disp': True,  # Display convergence messages
    'eps': 1e-8
}

options_nm = {
    'disp': True,  # Display convergence messages
}



### To be used for Synthetic data when you know true parameter values
# errors = []
# iterations = []

# def callback(xk):
#     print(f"Current parameter values: {xk}")
#     # err = np.linalg.norm(xk - trueparam)/np.linalg.norm(trueparam)
#     # print("relative error is", err)
#     errors.append(err)
#     iterations.append(len(errors))
 
val = 0.05
bounds = [(a0-val, a0+val), (a1-val, a1+val), (a2-val, a2+val), (a3-val, a3+val), (a4-val, a4+val), (a5-val, a5+val), (a6-val, a6+val), (a7-val, a7+val), (0, 0.001*total), (0, 0.001*total)]
          


res = minimize(loglikelihood, param,method='L-BFGS-B', options = options_bfgs)

# res = minimize(loglikelihood, param,method='Nelder-Mead',bounds=bounds, options=options_nm)

### To be used for Synthetic data when you know true parameter values
# path = './figs'
# filepath =  os.path.join(path,'relative_error.pdf')
# # Plot the error vs iteration
# # plt.figure()
# # plt.plot(iterations, errors, marker='o')
# # plt.xlabel('Iteration')
# # plt.ylabel('Relative error norm')
# # # plt.title('Relative error norm vs iteration')
# # plt.grid(True)
# # plt.savefig(filepath)
# # plt.show()


print(res)
param_mle = res.x

print("initial guesses" ,param)
print("MLE value", res.x)
# Out:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5722/3343654625.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if int(I_synthetic[0]) != 0:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5722/3343654625.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[0]),1)+1)) #log factorial
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5722/3343654625.py:42: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loglik = loglik + (math.lgamma(I_synthetic[0]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[0]*np.log(1-p))
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5722/3343654625.py:78: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if int(I_synthetic[idxmoh]) != 0:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5722/3343654625.py:79: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxmoh]),1)+1)) #log factorial
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5722/3343654625.py:83: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loglik = loglik + (math.lgamma(I_synthetic[idxmoh]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxmoh]*np.log(1-p))
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.37222D+04    |proj g|=  1.64137D+06
#  This problem is unconstrained.
# At iterate    1    f=  2.53166D+03    |proj g|=  5.28293D+05
#
# At iterate    2    f=  1.59422D+03    |proj g|=  5.13287D+04
#
# At iterate    3    f=  1.53252D+03    |proj g|=  5.49163D+04
#
# At iterate    4    f=  1.32154D+03    |proj g|=  9.29933D+04
#
# At iterate    5    f=  1.21119D+03    |proj g|=  6.01479D+04
#
# At iterate    6    f=  1.18451D+03    |proj g|=  1.60031D+04
#
# At iterate    7    f=  1.17854D+03    |proj g|=  2.06902D+04
#
# At iterate    8    f=  1.17271D+03    |proj g|=  3.73656D+04
#
# At iterate    9    f=  1.15418D+03    |proj g|=  6.94295D+04
#
# At iterate   10    f=  1.11747D+03    |proj g|=  1.02683D+05
#
# At iterate   11    f=  1.05292D+03    |proj g|=  1.19730D+05
#
# At iterate   12    f=  9.87191D+02    |proj g|=  8.68158D+04
#
# At iterate   13    f=  9.58383D+02    |proj g|=  2.97487D+04
#
# At iterate   14    f=  9.53972D+02    |proj g|=  4.54101D+03
#
# At iterate   15    f=  9.53593D+02    |proj g|=  4.61775D+03
#
# At iterate   16    f=  9.53277D+02    |proj g|=  4.60651D+03
#
# At iterate   17    f=  9.51144D+02    |proj g|=  8.85149D+03
#
# At iterate   18    f=  9.45963D+02    |proj g|=  1.51647D+04
#
# At iterate   19    f=  9.34175D+02    |proj g|=  2.38434D+04
#
# At iterate   20    f=  9.15067D+02    |proj g|=  2.98520D+04
#
# At iterate   21    f=  8.96345D+02    |proj g|=  1.68637D+04
#
# At iterate   22    f=  8.89852D+02    |proj g|=  1.91724D+04
#
# At iterate   23    f=  8.88566D+02    |proj g|=  3.08694D+03
#
# At iterate   24    f=  8.88043D+02    |proj g|=  1.31680D+03
#
# At iterate   25    f=  8.87874D+02    |proj g|=  1.87352D+03
#
# At iterate   26    f=  8.87409D+02    |proj g|=  2.70614D+03
#
# At iterate   27    f=  8.86269D+02    |proj g|=  3.76483D+03
#
# At iterate   28    f=  8.84016D+02    |proj g|=  4.90295D+03
#
# At iterate   29    f=  8.79734D+02    |proj g|=  5.97068D+03
#
# At iterate   30    f=  8.74912D+02    |proj g|=  6.18313D+03
#
# At iterate   31    f=  8.73834D+02    |proj g|=  3.74922D+03
#
# At iterate   32    f=  8.72851D+02    |proj g|=  1.18463D+03
#
# At iterate   33    f=  8.72683D+02    |proj g|=  5.28792D+02
#
# At iterate   34    f=  8.72664D+02    |proj g|=  7.34792D+02
#
# At iterate   35    f=  8.72609D+02    |proj g|=  5.19457D+02
#
# At iterate   36    f=  8.72487D+02    |proj g|=  1.52926D+03
#
# At iterate   37    f=  8.72064D+02    |proj g|=  2.66715D+03
#
# At iterate   38    f=  8.70858D+02    |proj g|=  5.26396D+03
#
# At iterate   39    f=  8.68499D+02    |proj g|=  7.13753D+03
#
# At iterate   40    f=  8.64972D+02    |proj g|=  1.19761D+04
#
# At iterate   41    f=  8.62040D+02    |proj g|=  2.10233D+03
#
# At iterate   42    f=  8.60959D+02    |proj g|=  2.58563D+03
#
# At iterate   43    f=  8.60786D+02    |proj g|=  2.91804D+03
#
# At iterate   44    f=  8.60689D+02    |proj g|=  1.18464D+03
#
# At iterate   45    f=  8.60654D+02    |proj g|=  7.78184D+02
#
# At iterate   46    f=  8.60414D+02    |proj g|=  2.28914D+03
#
# At iterate   47    f=  8.60069D+02    |proj g|=  4.01297D+03
#
# At iterate   48    f=  8.59417D+02    |proj g|=  5.12600D+03
#
# At iterate   49    f=  8.58827D+02    |proj g|=  3.58477D+03
#
# At iterate   50    f=  8.58554D+02    |proj g|=  2.27286D+03
#
# At iterate   51    f=  8.58493D+02    |proj g|=  7.20268D+02
#
# At iterate   52    f=  8.58453D+02    |proj g|=  1.04870D+03
#
# At iterate   53    f=  8.58408D+02    |proj g|=  1.43494D+03
#
# At iterate   54    f=  8.58245D+02    |proj g|=  1.90286D+03
#
# At iterate   55    f=  8.58145D+02    |proj g|=  9.61804D+03
#
# At iterate   56    f=  8.57608D+02    |proj g|=  5.78345D+03
#
# At iterate   57    f=  8.56311D+02    |proj g|=  1.22650D+03
#
# At iterate   58    f=  8.53702D+02    |proj g|=  7.67446D+03
#
# At iterate   59    f=  8.49853D+02    |proj g|=  1.29296D+04
#
# At iterate   60    f=  8.46716D+02    |proj g|=  1.01148D+04
#
# At iterate   61    f=  8.45463D+02    |proj g|=  3.77976D+03
#
# At iterate   62    f=  8.45326D+02    |proj g|=  9.57448D+02
#
# At iterate   63    f=  8.45318D+02    |proj g|=  7.76222D+01
#
# At iterate   64    f=  8.45316D+02    |proj g|=  1.18618D+02
#
# At iterate   65    f=  8.45315D+02    |proj g|=  6.76300D+01
#
# At iterate   66    f=  8.45314D+02    |proj g|=  6.87290D+01
#
# At iterate   67    f=  8.45313D+02    |proj g|=  2.08961D+02
#
# At iterate   68    f=  8.45313D+02    |proj g|=  2.16318D+02
#
# At iterate   69    f=  8.45298D+02    |proj g|=  1.52747D+03
#
# At iterate   70    f=  8.45265D+02    |proj g|=  6.49797D+02
#
# At iterate   71    f=  8.45248D+02    |proj g|=  1.01038D+02
#
# At iterate   72    f=  8.45245D+02    |proj g|=  7.22323D+01
#
# At iterate   73    f=  8.45243D+02    |proj g|=  7.27493D+01
#
# At iterate   74    f=  8.45242D+02    |proj g|=  2.88630D+02
#
# At iterate   75    f=  8.45230D+02    |proj g|=  3.72572D+02
#
# At iterate   76    f=  8.45207D+02    |proj g|=  2.74537D+02
#
# At iterate   77    f=  8.45175D+02    |proj g|=  1.17581D+02
#
# At iterate   78    f=  8.45172D+02    |proj g|=  7.13007D+02
#
# At iterate   79    f=  8.45165D+02    |proj g|=  6.44536D+01
#
# At iterate   80    f=  8.45165D+02    |proj g|=  4.70318D+01
#
# At iterate   81    f=  8.45164D+02    |proj g|=  1.21239D+02
#
# At iterate   82    f=  8.45162D+02    |proj g|=  7.63878D+01
#
# At iterate   83    f=  8.45160D+02    |proj g|=  8.00973D+01
#
# At iterate   84    f=  8.45157D+02    |proj g|=  9.24770D+01
#
# At iterate   85    f=  8.45157D+02    |proj g|=  1.04080D+02
#
# At iterate   86    f=  8.45155D+02    |proj g|=  7.15432D+01
#
# At iterate   87    f=  8.45151D+02    |proj g|=  5.52203D+01
#
# At iterate   88    f=  8.45143D+02    |proj g|=  6.50303D+01
#
# At iterate   89    f=  8.45142D+02    |proj g|=  1.19814D+02
#
# At iterate   90    f=  8.45139D+02    |proj g|=  1.37866D+02
#
# At iterate   91    f=  8.45138D+02    |proj g|=  1.57286D+02
#
# At iterate   92    f=  8.45137D+02    |proj g|=  5.56068D+01
#
# At iterate   93    f=  8.45137D+02    |proj g|=  8.14117D+01
#
# At iterate   94    f=  8.45136D+02    |proj g|=  4.79635D+01
#
# At iterate   95    f=  8.45136D+02    |proj g|=  6.75519D+01
#
# At iterate   96    f=  8.45136D+02    |proj g|=  3.27640D+01
#
# At iterate   97    f=  8.45136D+02    |proj g|=  3.40661D+01
#
# At iterate   98    f=  8.45136D+02    |proj g|=  3.46215D+01
#
# At iterate   99    f=  8.45135D+02    |proj g|=  8.01126D+01
#
# At iterate  100    f=  8.45134D+02    |proj g|=  1.52175D+02
#
# At iterate  101    f=  8.45133D+02    |proj g|=  2.93068D+02
#
# At iterate  102    f=  8.45132D+02    |proj g|=  5.65803D+01
#
# At iterate  103    f=  8.45132D+02    |proj g|=  2.43982D+01
#
# At iterate  104    f=  8.45132D+02    |proj g|=  7.98181D+00
#
# At iterate  105    f=  8.45132D+02    |proj g|=  1.67607D+00
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 845.1317882582504
#         x: [ 1.308e-01 -8.540e-02  2.654e-02 -3.356e-02  3.423e-02
#              5.762e-02 -9.914e-02  1.294e-01  9.600e+01  9.600e+01]
#       nit: 106
#       jac: [-3.500e+00 -3.042e+00 -2.558e+00 -1.137e+00 -5.830e-01
#             -3.078e-01 -1.422e-01 -8.847e-02  4.609e-01  5.244e-01]
#      nfev: 1375
#      njev: 125
#  hess_inv: <10x10 LbfgsInvHessProduct with dtype=float64>
# At iterate  106    f=  8.45132D+02    |proj g|=  3.49984D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10    106    125      1     0     0   3.500D+00   8.451D+02
#   F =   845.13178825825037
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# initial guesses [ 1.0e-01 -9.0e-02  4.0e-02 -2.0e-02  1.0e-02  4.0e-02 -1.0e-02  4.0e-02
#   9.6e+01  9.6e+01]
# MLE value [ 1.30772565e-01 -8.54004108e-02  2.65404473e-02 -3.35566339e-02
#   3.42296008e-02  5.76184965e-02 -9.91353950e-02  1.29417795e-01
#   9.59998348e+01  9.59998105e+01]

# %% [markdown]
# ### MLE Fit

# %%
########### CHANGE HERE #############
### Add the necessary parameter values which are already calibrated along with the current parameters ##############

beta_i[:,0] = param_mle[0] +  param_mle[1]/(1 + np.exp((t1-tmoh)))  \
+ param_mle[2]/(1 + np.exp((t2-tmoh))) \
+ param_mle[3]/(1 + np.exp((t3-tmoh))) \
+ param_mle[4]/(1 + np.exp((t4-tmoh))) \
+ param_mle[5]/(1 + np.exp((t5-tmoh))) \
+ param_mle[6]/(1 + np.exp((t6-tmoh))) \
+ param_mle[7]/(1 + np.exp((t7-tmoh))) \
# + param_mle[8]/(1 + np.exp((t8-tmoh)))


E[0,0] = param_mle[8]

I[0,0] = param_mle[9]

###########################################

beta_e[:,0] = beta_i[:,0]
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


## load saved true infection data

# data = np.loadtxt(f'{datapath}/toronto_synthetic_truth_all.csv',delimiter=",")
# I_truth = data[0:len(tmoh),2]

fig1, ax1 = plt.subplots(figsize=(6, 4))
# plt.plot(t[:tlim], I_synthetic[:tlim,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh[:int(tlim*ndiv)], I[:int(tlim*ndiv),0], '-',linewidth=2, label='MLE fit')
# plt.plot(tmoh[:int(tlim*ndiv)], I_truth, '-',linewidth=2, label='True model')
plt.plot(t[:tlim], Data[:tlim,2], '-',linewidth=2, label='True model')
plt.legend(loc='best')
plt.xlabel('Time (days)')
plt.xlim([0,tlim])
plt.ylabel('Infected cases')
plt.grid()
plt.savefig(f'{figpath}/MLE_fit.pdf', bbox_inches='tight')
plt.show()


## load saved true model of beta

# file = np.loadtxt(f'{datapath}/toronto_true_beta.csv')
# beta_truth = file[0:len(tmoh)]


fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Infection rate - MLE fit')
# plt.plot(tmoh, beta_truth, label='Infection rate - Truth')
plt.legend(loc='best')
plt.savefig(f'{figpath}/beta_fit.pdf',  bbox_inches='tight')
plt.show()
