# %% [markdown]
# ## Sequntial maximum likelihood estimation of infection rate parameters of a single PHU using negative Binomial

# %%
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

from scipy.optimize import minimize

##### CHANGE HERE #############
### Use the time up to which you need to estimate the parameters of sigmoid
dt = 0.1
tstart = 0
tlim = 210
t = np.arange(tstart, tlim, 1)


### keep it always starting at 0
tmoh = np.arange(0, tlim, dt)

ndiv = 1/dt


##### CHANGE HERE #############

###### If you have your own data, load it here #######
### Currently loaded infection data from MOH, for April 2020 to March 2021

PHU_path = '/Users/sudhipv/documents/coupled_compartment/PHU_Data/'
datapath = '/Users/sudhipv/documents/coupled_compartment/data/'
figpath = '/Users/sudhipv/documents/coupled_compartment/figs/mle'
Data = np.zeros([365,4])

files = os.listdir(PHU_path)

target_file1 = f'{PHU_path}/30-Toronto.csv'
target_file2 = f'{PHU_path}/34-York.csv'
target_file3 = f'{PHU_path}/04-Durham.csv'
target_file4 = f'{PHU_path}/22-PeelRegion.csv'

Data[:,0] = np.genfromtxt(target_file1, delimiter=',')
Data[:,1] = np.genfromtxt(target_file2, delimiter=',')
Data[:,2] = np.genfromtxt(target_file3, delimiter=',')
Data[:,3] = np.genfromtxt(target_file4, delimiter=',')


population_by_phu = np.genfromtxt(f'{PHU_path}/population_by_phu.csv', delimiter=',')


N_city = 1
# Preallocate compartments
S = np.zeros((len(tmoh),N_city))
E = np.zeros((len(tmoh),N_city))
I = np.zeros((len(tmoh),N_city))
R = np.zeros((len(tmoh),N_city))
D = np.zeros((len(tmoh),N_city))
N = np.zeros((len(tmoh),N_city))

I_synthetic = np.zeros((len(t),N_city))

##### CHANGE HERE #############
## Observed data

### MOH data - No true solution
I_synthetic[:,0] =  Data[tstart:tlim,0]

### Synthetic data - true solution
# file = np.loadtxt(f'{datapath}/coupled_synth_data_r100.csv')
# I_synthetic[:,0] = file[tstart:tlim]

##############################

L_Force = np.zeros((len(tmoh),N_city))

##### CHANGE HERE #############
total = population_by_phu[29,1]
##### CHANGE HERE #############


# Model parameters - Taken from Southern Ontario - COVID MBE paper
gamma_e = 1/15
gamma_i = 1/5
gamma_r = 1/11
gamma_d = 1/750

beta_e = np.zeros((len(tmoh),N_city)) 
beta_i = np.zeros((len(tmoh),N_city))

beta_calibrated = np.zeros((len(tmoh),N_city))


print("initial infected",I[0,0])

print("total population",total)


#### PEEL - 234 , 1451022

#### Toronto - 430 , 2794356

### York - 212, 1173334

### Durham - 94   - 696992


mpl.rcParams.update({'font.size':14})
# Out:
# initial infected 0.0
# total population 2794356.0

# %%
################### Durham ##########################################################
nparam = 10
param = np.ones(nparam)
##### CHANGE HERE ############
### Use the parameters which needs to be included in the sum of sigmoids model for MLE estimation
### When doing sequential calibration, include all the parameters until that time which are already calibrated. 


##### CHANGE HERE #############
E[0,0] = 430
I[0,0] = 430
##############################
R[0,0] = 0
D[0,0] = 0
N[0,0] = total
S[0,0] = N[0,0] - E[0,0] - I[0,0] - R[0,0] - D[0,0]


### Initial guesses of your parameters
a0 = 0.1
a1 = -0.05
t1 =  20
a2 =   0.02
t2 =  35
a3 =   -0.01
t3 = 60
a4 =  0.02
t4 = 80
a5 =  0.04
t5 = 140
a6 =  -0.05
t6 = 180
a7 =  0.03
t7 = 190
# a8 =  -0.03
# t8 = 230

### Manually Tuned parameters for MOH infection data

# a0 =   0.15
# a1 =  -0.1
# t1 =  20
# a2 =   0.05
# t2 =  35
# a3 =   -0.07
# t3 = 60
# a4 =  0.035
# t4 = 80
# a5 =  0.08
# t5 = 140
# a6 =  -0.065
# t6 = 180
# a7 =  0.025
# t7 = 190
# a8 =  -0.015
# t8 = 230


### CHANGE HERE 
beta_i[:,0] = a0  + a1/(1 + np.exp((t1-tmoh))) \
+ a2/(1 + np.exp((t2-tmoh))) \
+ a3/(1 + np.exp((t3-tmoh))) \
+ a4/(1 + np.exp((t4-tmoh))) \
+ a5/(1 + np.exp((t5-tmoh))) \
+ a6/(1 + np.exp((t6-tmoh))) \
+ a7/(1 + np.exp((t7-tmoh))) \
# + a8/(1 + np.exp((t8-tmoh)))

beta_e[:,0] = beta_i[:,0]



#### DEFINE THE PARAMETERS TO BE ESTIMATED 

### CHANGE HERE 
param = np.array([a0,a1,a2,a3,a4,a5,a6,a7,E[0,0],I[0,0]])

# %%
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]

  if( kk%ndiv == 0):
      idxmoh = int(kk/ndiv)



fig1, ax1 = plt.subplots(figsize=(6, 4))
ax1.set_xlim([0,tlim])
ax1.set_xlabel('Time (days)')
ax1.set_ylabel('Infected cases') 
ax1.grid()
plt.plot(t, I_synthetic[:,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh, I[:,0], '-',linewidth=2, label='Initial guess model output')
ax1.legend(loc='best')
# plt.savefig('./figs/noisy_data.pdf',  bbox_inches='tight')
plt.show()



fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Sum of sigmoid model')
ax1.legend(loc='best')
# plt.savefig('./figs/beta.pdf',  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Applying scipy optimization library

# %%
#### CHANGE HERE 
### decrease p to reduce r and thus dispersion, increase p to get more dispersion
r = 100 ### Number of success


def loglikelihood(param):
      
    idxmoh = 1
    idxdata= 0

    loglik = 0

    FoI = np.zeros((len(tmoh),1))

    E[0,0] = param[8]

    I[0,0] = param[9]

############### CHANGE HERE #################
###### Update the model of beta to include the parameter which needs to be estimated along with the known paramters until that time
    beta_i[:,0] = param[0] + param[1]/(1 + np.exp((t1-tmoh))) \
    + param[2]/(1 + np.exp((t2-tmoh)))  \
    + param[3]/(1 + np.exp((t3-tmoh))) \
    + param[4]/(1 + np.exp((t4-tmoh))) \
    + param[5]/(1 + np.exp((t5-tmoh))) \
    + param[6]/(1 + np.exp((t6-tmoh))) \
    + param[7]/(1 + np.exp((t7-tmoh))) \
    # + param[8]/(1 + np.exp((t8-tmoh)))
    

    beta_e[:,0] = beta_i[:,0]   


######### For adding the initial condition value to likelihood
    logNfac = 0.0

    if int(I_synthetic[0]) != 0:
        logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[0]),1)+1)) #log factorial

    # r = (p*I[kk,0])/(1-p)
    p = r /(I[0,0] + r)
    loglik = loglik + (math.lgamma(I_synthetic[0]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[0]*np.log(1-p))

    for kk in range(1,len(tmoh)):

            FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

            S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
            E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
            I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
            R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
            D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
            N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


            ## For collecting the model output only at data points
            if( kk%ndiv == 0 ):
                idxmoh = int(kk/ndiv)


                if(tstart != 0):
                    if(idxmoh >= tstart and idxmoh < tlim):
                         
                        logNfac = 0.0

                        if int(I_synthetic[idxdata]) != 0:
                            logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxdata]),1)+1)) #log factorial

                        # r = (p*I[kk,0])/(1-p)
                        p = r /(I[kk,0] + r)
                        loglik = loglik + (math.lgamma(I_synthetic[idxdata]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxdata]*np.log(1-p))
                        idxdata+=1
            
                else:

                    logNfac = 0.0

                    if int(I_synthetic[idxmoh]) != 0:
                        logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxmoh]),1)+1)) #log factorial

                    # r = (p*I[kk,0])/(1-p)
                    p = r /(I[kk,0] + r)
                    loglik = loglik + (math.lgamma(I_synthetic[idxmoh]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxmoh]*np.log(1-p))

    
    return -loglik



options_bfgs = {
    'gtol': 1e-12,  # Gradient norm tolerance for convergence
    'disp': True,  # Display convergence messages
    'eps': 1e-8
}

options_nm = {
    'disp': True,  # Display convergence messages
}



### To be used for Synthetic data when you know true parameter values
# errors = []
# iterations = []

# def callback(xk):
#     print(f"Current parameter values: {xk}")
#     # err = np.linalg.norm(xk - trueparam)/np.linalg.norm(trueparam)
#     # print("relative error is", err)
#     errors.append(err)
#     iterations.append(len(errors))
 
val = 0.05
bounds = [(a0-val, a0+val), (a1-val, a1+val), (a2-val, a2+val), (a3-val, a3+val), (a4-val, a4+val), (a5-val, a5+val), (a6-val, a6+val), (a7-val, a7+val), (0, 0.001*total), (0, 0.001*total)]
          


res = minimize(loglikelihood, param,method='L-BFGS-B', options = options_bfgs)

# res = minimize(loglikelihood, param,method='Nelder-Mead',bounds=bounds, options=options_nm)

### To be used for Synthetic data when you know true parameter values
# path = './figs'
# filepath =  os.path.join(path,'relative_error.pdf')
# # Plot the error vs iteration
# # plt.figure()
# # plt.plot(iterations, errors, marker='o')
# # plt.xlabel('Iteration')
# # plt.ylabel('Relative error norm')
# # # plt.title('Relative error norm vs iteration')
# # plt.grid(True)
# # plt.savefig(filepath)
# # plt.show()


print(res)
param_mle = res.x

print("initial guesses" ,param)
print("MLE value", res.x)
# Out:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5232/3343654625.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if int(I_synthetic[0]) != 0:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5232/3343654625.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[0]),1)+1)) #log factorial
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5232/3343654625.py:42: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loglik = loglik + (math.lgamma(I_synthetic[0]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[0]*np.log(1-p))
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5232/3343654625.py:78: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if int(I_synthetic[idxmoh]) != 0:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5232/3343654625.py:79: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxmoh]),1)+1)) #log factorial
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_5232/3343654625.py:83: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loglik = loglik + (math.lgamma(I_synthetic[idxmoh]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxmoh]*np.log(1-p))
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.46934D+04    |proj g|=  2.92531D+06
#
# At iterate    1    f=  7.23167D+03    |proj g|=  3.78374D+05
#
# At iterate    2    f=  6.90427D+03    |proj g|=  2.76681D+05
#
# At iterate    3    f=  6.50116D+03    |proj g|=  3.71599D+05
#
# At iterate    4    f=  6.16000D+03    |proj g|=  4.64613D+05
#
# At iterate    5    f=  4.49664D+03    |proj g|=  6.45172D+05
#
# At iterate    6    f=  3.53195D+03    |proj g|=  3.16982D+05
#
# At iterate    7    f=  3.27040D+03    |proj g|=  7.29091D+04
#
# At iterate    8    f=  3.24469D+03    |proj g|=  6.69627D+04
#
# At iterate    9    f=  3.20636D+03    |proj g|=  7.65716D+04
#
# At iterate   10    f=  3.08598D+03    |proj g|=  1.52975D+05
#
# At iterate   11    f=  2.82510D+03    |proj g|=  2.53673D+05
#
# At iterate   12    f=  2.31697D+03    |proj g|=  3.22153D+05
#
# At iterate   13    f=  1.70720D+03    |proj g|=  2.33710D+05
#
# At iterate   14    f=  1.45123D+03    |proj g|=  1.44312D+05
#
# At iterate   15    f=  1.42034D+03    |proj g|=  2.14613D+04
#
# At iterate   16    f=  1.38821D+03    |proj g|=  5.22384D+03
#
# At iterate   17    f=  1.38314D+03    |proj g|=  4.57829D+03
#
# At iterate   18    f=  1.37441D+03    |proj g|=  4.82403D+03
#
# At iterate   19    f=  1.32594D+03    |proj g|=  1.11361D+04
#
# At iterate   20    f=  1.30946D+03    |proj g|=  1.63402D+04
#
# At iterate   21    f=  1.29325D+03    |proj g|=  5.33324D+03
#
# At iterate   22    f=  1.28435D+03    |proj g|=  6.00961D+03
#
# At iterate   23    f=  1.28289D+03    |proj g|=  1.85916D+03
#
# At iterate   24    f=  1.27954D+03    |proj g|=  7.49610D+03
#
# At iterate   25    f=  1.27596D+03    |proj g|=  1.03593D+04
#
# At iterate   26    f=  1.27514D+03    |proj g|=  1.08555D+04
#
# At iterate   27    f=  1.26966D+03    |proj g|=  3.33146D+03
#
# At iterate   28    f=  1.26740D+03    |proj g|=  4.00519D+03
#
# At iterate   29    f=  1.26629D+03    |proj g|=  1.98290D+03
#
# At iterate   30    f=  1.26487D+03    |proj g|=  4.35854D+03
#
# At iterate   31    f=  1.26337D+03    |proj g|=  7.30755D+03
#
# At iterate   32    f=  1.25864D+03    |proj g|=  1.27481D+04
#
# At iterate   33    f=  1.25069D+03    |proj g|=  1.64972D+04
#
# At iterate   34    f=  1.23973D+03    |proj g|=  1.47141D+04
#
# At iterate   35    f=  1.23487D+03    |proj g|=  3.20663D+03
#
# At iterate   36    f=  1.23067D+03    |proj g|=  5.12465D+03
#
# At iterate   37    f=  1.23057D+03    |proj g|=  3.35400D+03
#
# At iterate   38    f=  1.23014D+03    |proj g|=  3.36980D+03
#
# At iterate   39    f=  1.22963D+03    |proj g|=  4.01397D+03
#
# At iterate   40    f=  1.22863D+03    |proj g|=  1.89943D+03
#
# At iterate   41    f=  1.22796D+03    |proj g|=  1.37205D+03
#
# At iterate   42    f=  1.22596D+03    |proj g|=  1.94642D+03
#
# At iterate   43    f=  1.22471D+03    |proj g|=  2.42323D+03
#
# At iterate   44    f=  1.22295D+03    |proj g|=  1.01404D+03
#
# At iterate   45    f=  1.22086D+03    |proj g|=  2.46014D+03
#
# At iterate   46    f=  1.22059D+03    |proj g|=  1.61114D+03
#
# At iterate   47    f=  1.21995D+03    |proj g|=  9.75282D+02
#
# At iterate   48    f=  1.21992D+03    |proj g|=  4.24783D+03
#
# At iterate   49    f=  1.21914D+03    |proj g|=  2.81261D+02
#
# At iterate   50    f=  1.21912D+03    |proj g|=  3.82062D+02
#
# At iterate   51    f=  1.21911D+03    |proj g|=  1.66663D+02
#
# At iterate   52    f=  1.21910D+03    |proj g|=  1.06293D+02
#
# At iterate   53    f=  1.21910D+03    |proj g|=  1.61774D+02
#
# At iterate   54    f=  1.21909D+03    |proj g|=  2.55840D+02
#
# At iterate   55    f=  1.21907D+03    |proj g|=  3.66703D+02
#
# At iterate   56    f=  1.21897D+03    |proj g|=  5.93229D+02
#
# At iterate   57    f=  1.21881D+03    |proj g|=  1.07550D+03
#
# At iterate   58    f=  1.21874D+03    |proj g|=  1.00645D+03
#
# At iterate   59    f=  1.21865D+03    |proj g|=  5.15292D+03
#
# At iterate   60    f=  1.21844D+03    |proj g|=  2.78645D+03
#
# At iterate   61    f=  1.21828D+03    |proj g|=  3.03062D+02
#
# At iterate   62    f=  1.21827D+03    |proj g|=  3.42554D+02
#
# At iterate   63    f=  1.21827D+03    |proj g|=  3.37136D+01
#
# At iterate   64    f=  1.21827D+03    |proj g|=  6.25603D+01
#
# At iterate   65    f=  1.21827D+03    |proj g|=  5.55110D+01
#
# At iterate   66    f=  1.21827D+03    |proj g|=  7.06377D+01
#
# At iterate   67    f=  1.21827D+03    |proj g|=  3.72086D+01
#
# At iterate   68    f=  1.21826D+03    |proj g|=  7.04040D+01
#
# At iterate   69    f=  1.21826D+03    |proj g|=  7.82980D+01
#
# At iterate   70    f=  1.21826D+03    |proj g|=  2.37567D+01
#
# At iterate   71    f=  1.21826D+03    |proj g|=  5.79004D+01
#
# At iterate   72    f=  1.21826D+03    |proj g|=  1.85589D+01
#
# At iterate   73    f=  1.21826D+03    |proj g|=  3.03563D+01
#
# At iterate   74    f=  1.21826D+03    |proj g|=  7.11391D+01
#
# At iterate   75    f=  1.21826D+03    |proj g|=  6.02735D+01
#
# At iterate   76    f=  1.21826D+03    |proj g|=  1.17446D+01
#
# At iterate   77    f=  1.21826D+03    |proj g|=  1.32009D+00
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1218.2625557573472
#         x: [ 1.480e-01 -1.062e-01  5.966e-02 -6.093e-02  2.010e-02
#              8.614e-02 -4.695e-02 -5.140e-03  4.300e+02  4.300e+02]
#       nit: 78
#       jac: [ 5.999e-01  6.237e-01  6.226e-01  3.264e-01 -2.728e-01
#             -1.792e+00 -3.270e-01 -9.672e-02 -5.252e-03  3.417e-02]
#      nfev: 1034
#      njev: 94
#  hess_inv: <10x10 LbfgsInvHessProduct with dtype=float64>
# At iterate   78    f=  1.21826D+03    |proj g|=  1.79218D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     78     94      1     0     0   1.792D+00   1.218D+03
#   F =   1218.2625557573472
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# initial guesses [ 1.0e-01 -5.0e-02  2.0e-02 -1.0e-02  2.0e-02  4.0e-02 -5.0e-02  3.0e-02
#   4.3e+02  4.3e+02]
# MLE value [ 1.48024018e-01 -1.06192624e-01  5.96551784e-02 -6.09307671e-02
#   2.01019087e-02  8.61353607e-02 -4.69533788e-02 -5.14049636e-03
#   4.30000013e+02  4.30000004e+02]

# %% [markdown]
# ### MLE Fit

# %%
########### CHANGE HERE #############
### Add the necessary parameter values which are already calibrated along with the current parameters ##############

beta_i[:,0] = param_mle[0] +  param_mle[1]/(1 + np.exp((t1-tmoh)))  \
+ param_mle[2]/(1 + np.exp((t2-tmoh))) \
+ param_mle[3]/(1 + np.exp((t3-tmoh))) \
+ param_mle[4]/(1 + np.exp((t4-tmoh))) \
+ param_mle[5]/(1 + np.exp((t5-tmoh))) \
+ param_mle[6]/(1 + np.exp((t6-tmoh))) \
+ param_mle[7]/(1 + np.exp((t7-tmoh))) \
# + param_mle[8]/(1 + np.exp((t8-tmoh)))


E[0,0] = param_mle[8]

I[0,0] = param_mle[9]

###########################################

beta_e[:,0] = beta_i[:,0]
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


## load saved true infection data

# data = np.loadtxt(f'{datapath}/toronto_synthetic_truth_all.csv',delimiter=",")
# I_truth = data[0:len(tmoh),2]

fig1, ax1 = plt.subplots(figsize=(6, 4))
# plt.plot(t[:tlim], I_synthetic[:tlim,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh[:int(tlim*ndiv)], I[:int(tlim*ndiv),0], '-',linewidth=2, label='MLE fit')
# plt.plot(tmoh[:int(tlim*ndiv)], I_truth, '-',linewidth=2, label='True model')
plt.plot(t[:tlim], Data[:tlim,0], '-',linewidth=2, label='True model')
plt.legend(loc='best')
plt.xlabel('Time (days)')
plt.xlim([0,tlim])
plt.ylabel('Infected cases')
plt.grid()
plt.savefig(f'{figpath}/MLE_fit.pdf', bbox_inches='tight')
plt.show()


## load saved true model of beta

# file = np.loadtxt(f'{datapath}/toronto_true_beta.csv')
# beta_truth = file[0:len(tmoh)]


fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Infection rate - MLE fit')
# plt.plot(tmoh, beta_truth, label='Infection rate - Truth')
plt.legend(loc='best')
plt.savefig(f'{figpath}/beta_fit.pdf',  bbox_inches='tight')
plt.show()
