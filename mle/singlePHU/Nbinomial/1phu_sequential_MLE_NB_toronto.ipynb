# %% [markdown]
# ## Sequntial maximum likelihood estimation of infection rate parameters of a single PHU using negative Binomial

# %%
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

from scipy.optimize import minimize

##### CHANGE HERE #############
### Use the time up to which you need to estimate the parameters of sigmoid
dt = 0.1
tstart = 0
tlim = 210
t = np.arange(tstart, tlim, 1)


### keep it always starting at 0
tmoh = np.arange(0, tlim, dt)

ndiv = 1/dt


##### CHANGE HERE #############

###### If you have your own data, load it here #######
### Currently loaded infection data from MOH, for April 2020 to March 2021

PHU_path = '/Users/sudhipv/documents/coupled_compartment/PHU_Data'
datapath = '/Users/sudhipv/documents/coupled_compartment/data'
figpath = '/Users/sudhipv/documents/coupled_compartment/figs/mle'
Data = np.zeros([365,4])

files = os.listdir(PHU_path)

target_file1 = f'{PHU_path}/30-Toronto.csv'
target_file2 = f'{PHU_path}/34-York.csv'
target_file3 = f'{PHU_path}/04-Durham.csv'
target_file4 = f'{PHU_path}/22-PeelRegion.csv'

Data[:,0] = np.genfromtxt(target_file1, delimiter=',')
Data[:,1] = np.genfromtxt(target_file2, delimiter=',')
Data[:,2] = np.genfromtxt(target_file3, delimiter=',')
Data[:,3] = np.genfromtxt(target_file4, delimiter=',')


population_by_phu = np.genfromtxt(f'{PHU_path}/population_by_phu.csv', delimiter=',')


N_city = 1
# Preallocate compartments
S = np.zeros((len(tmoh),N_city))
E = np.zeros((len(tmoh),N_city))
I = np.zeros((len(tmoh),N_city))
R = np.zeros((len(tmoh),N_city))
D = np.zeros((len(tmoh),N_city))
N = np.zeros((len(tmoh),N_city))

I_synthetic = np.zeros((len(t),N_city))

##### CHANGE HERE #############
## Observed data

### MOH data - No true solution
# I_synthetic[:,0] =  Data[tstart:tlim,0]

### Synthetic data - true solution
file = np.loadtxt(f'{datapath}/coupled_synth_data_r100.csv', delimiter=',')
I_synthetic[:,0] = file[tstart:tlim,0]

##############################

L_Force = np.zeros((len(tmoh),N_city))

##### CHANGE HERE #############
total = population_by_phu[29,1]
##### CHANGE HERE #############


# Model parameters - Taken from Southern Ontario - COVID MBE paper
gamma_e = 1/15
gamma_i = 1/5
gamma_r = 1/11
gamma_d = 1/750

beta_e = np.zeros((len(tmoh),N_city)) 
beta_i = np.zeros((len(tmoh),N_city))

beta_calibrated = np.zeros((len(tmoh),N_city))


print("initial infected",I[0,0])

print("total population",total)


#### PEEL - 234 , 1451022

#### Toronto - 430 , 2794356

### York - 212, 1173334

### Durham - 94   - 696992


mpl.rcParams.update({'font.size':14})
# Out:
# initial infected 0.0
# total population 2794356.0

# %%
################### Durham ##########################################################
nparam = 10
param = np.ones(nparam)
##### CHANGE HERE ############
### Use the parameters which needs to be included in the sum of sigmoids model for MLE estimation
### When doing sequential calibration, include all the parameters until that time which are already calibrated. 


##### CHANGE HERE #############
E[0,0] = 430
I[0,0] = 430
##############################
R[0,0] = 0
D[0,0] = 0
N[0,0] = total
S[0,0] = N[0,0] - E[0,0] - I[0,0] - R[0,0] - D[0,0]


### Initial guesses of your parameters
a0 = 0.1
a1 = -0.05
t1 =  20
a2 =   0.02
t2 =  35
a3 =   -0.01
t3 = 60
a4 =  0.02
t4 = 80
a5 =  0.04
t5 = 140
a6 =  -0.02
t6 = 180
a7 =  0.06
t7 = 190
# a8 =  -0.03
# t8 = 230

### Manually Tuned parameters for MOH infection data

# a0 =   0.15
# a1 =  -0.1
# t1 =  20
# a2 =   0.05
# t2 =  35
# a3 =   -0.07
# t3 = 60
# a4 =  0.035
# t4 = 80
# a5 =  0.08
# t5 = 140
# a6 =  -0.065
# t6 = 180
# a7 =  0.025
# t7 = 190
# a8 =  -0.015
# t8 = 230


### CHANGE HERE 
beta_i[:,0] = a0  + a1/(1 + np.exp((t1-tmoh))) \
+ a2/(1 + np.exp((t2-tmoh))) \
+ a3/(1 + np.exp((t3-tmoh))) \
+ a4/(1 + np.exp((t4-tmoh))) \
+ a5/(1 + np.exp((t5-tmoh))) \
+ a6/(1 + np.exp((t6-tmoh))) \
+ a7/(1 + np.exp((t7-tmoh))) \
# + a8/(1 + np.exp((t8-tmoh)))

beta_e[:,0] = beta_i[:,0]



#### DEFINE THE PARAMETERS TO BE ESTIMATED 

### CHANGE HERE 
param = np.array([a0,a1,a2,a3,a4,a5,a6,a7,E[0,0],I[0,0]])

# %%
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]

  if( kk%ndiv == 0):
      idxmoh = int(kk/ndiv)



fig1, ax1 = plt.subplots(figsize=(6, 4))
ax1.set_xlim([0,tlim])
ax1.set_xlabel('Time (days)')
ax1.set_ylabel('Infected cases') 
ax1.grid()
plt.plot(t, I_synthetic[:,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh, I[:,0], '-',linewidth=2, label='Initial guess model output')
ax1.legend(loc='best')
# plt.savefig('./figs/noisy_data.pdf',  bbox_inches='tight')
plt.show()



fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Sum of sigmoid model')
ax1.legend(loc='best')
# plt.savefig('./figs/beta.pdf',  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Applying scipy optimization library

# %%
#### CHANGE HERE 
### decrease p to reduce r and thus dispersion, increase p to get more dispersion
r = 100 ### Number of success


def loglikelihood(param):
      
    idxmoh = 1
    idxdata= 0

    loglik = 0

    FoI = np.zeros((len(tmoh),1))

    E[0,0] = param[8]

    I[0,0] = param[9]

############### CHANGE HERE #################
###### Update the model of beta to include the parameter which needs to be estimated along with the known paramters until that time
    beta_i[:,0] = param[0] + param[1]/(1 + np.exp((t1-tmoh))) \
    + param[2]/(1 + np.exp((t2-tmoh)))  \
    + param[3]/(1 + np.exp((t3-tmoh))) \
    + param[4]/(1 + np.exp((t4-tmoh))) \
    + param[5]/(1 + np.exp((t5-tmoh))) \
    + param[6]/(1 + np.exp((t6-tmoh))) \
    + param[7]/(1 + np.exp((t7-tmoh))) \
    # + param[8]/(1 + np.exp((t8-tmoh)))
    

    beta_e[:,0] = beta_i[:,0]   


######### For adding the initial condition value to likelihood
    logNfac = 0.0

    if int(I_synthetic[0]) != 0:
        logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[0]),1)+1)) #log factorial

    # r = (p*I[kk,0])/(1-p)
    p = r /(I[0,0] + r)
    loglik = loglik + (math.lgamma(I_synthetic[0]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[0]*np.log(1-p))

    for kk in range(1,len(tmoh)):

            FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

            S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
            E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
            I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
            R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
            D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
            N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


            ## For collecting the model output only at data points
            if( kk%ndiv == 0 ):
                idxmoh = int(kk/ndiv)


                if(tstart != 0):
                    if(idxmoh >= tstart and idxmoh < tlim):
                         
                        logNfac = 0.0

                        if int(I_synthetic[idxdata]) != 0:
                            logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxdata]),1)+1)) #log factorial

                        # r = (p*I[kk,0])/(1-p)
                        p = r /(I[kk,0] + r)
                        loglik = loglik + (math.lgamma(I_synthetic[idxdata]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxdata]*np.log(1-p))
                        idxdata+=1
            
                else:

                    logNfac = 0.0

                    if int(I_synthetic[idxmoh]) != 0:
                        logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxmoh]),1)+1)) #log factorial

                    # r = (p*I[kk,0])/(1-p)
                    p = r /(I[kk,0] + r)
                    loglik = loglik + (math.lgamma(I_synthetic[idxmoh]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxmoh]*np.log(1-p))

    
    return -loglik



options_bfgs = {
    'gtol': 1e-12,  # Gradient norm tolerance for convergence
    'disp': True,  # Display convergence messages
    'eps': 1e-8
}

options_nm = {
    'disp': True,  # Display convergence messages
}



### To be used for Synthetic data when you know true parameter values
# errors = []
# iterations = []

# def callback(xk):
#     print(f"Current parameter values: {xk}")
#     # err = np.linalg.norm(xk - trueparam)/np.linalg.norm(trueparam)
#     # print("relative error is", err)
#     errors.append(err)
#     iterations.append(len(errors))
 
val = 0.05
bounds = [(a0-val, a0+val), (a1-val, a1+val), (a2-val, a2+val), (a3-val, a3+val), (a4-val, a4+val), (a5-val, a5+val), (a6-val, a6+val), (a7-val, a7+val), (0, 0.001*total), (0, 0.001*total)]
          


res = minimize(loglikelihood, param,method='L-BFGS-B', options = options_bfgs)

# res = minimize(loglikelihood, param,method='Nelder-Mead',bounds=bounds, options=options_nm)

### To be used for Synthetic data when you know true parameter values
# path = './figs'
# filepath =  os.path.join(path,'relative_error.pdf')
# # Plot the error vs iteration
# # plt.figure()
# # plt.plot(iterations, errors, marker='o')
# # plt.xlabel('Iteration')
# # plt.ylabel('Relative error norm')
# # # plt.title('Relative error norm vs iteration')
# # plt.grid(True)
# # plt.savefig(filepath)
# # plt.show()


print(res)
param_mle = res.x

print("initial guesses" ,param)
print("MLE value", res.x)
# Out:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_31988/3343654625.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if int(I_synthetic[0]) != 0:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_31988/3343654625.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[0]),1)+1)) #log factorial
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_31988/3343654625.py:42: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loglik = loglik + (math.lgamma(I_synthetic[0]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[0]*np.log(1-p))
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_31988/3343654625.py:78: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if int(I_synthetic[idxmoh]) != 0:
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_31988/3343654625.py:79: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   logNfac = np.sum(np.log(np.arange(0,int(I_synthetic[idxmoh]),1)+1)) #log factorial
# /var/folders/lr/4h04vl_92s3d0hrwg37l8g740000gn/T/ipykernel_31988/3343654625.py:83: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loglik = loglik + (math.lgamma(I_synthetic[idxmoh]+r) - (logNfac + math.lgamma(r)) + r*np.log(p) + I_synthetic[idxmoh]*np.log(1-p))
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02642D+04    |proj g|=  1.65496D+06
#  This problem is unconstrained.
# At iterate    1    f=  7.22284D+03    |proj g|=  2.52352D+05
#
# At iterate    2    f=  6.45634D+03    |proj g|=  3.44161D+05
#
# At iterate    3    f=  4.81321D+03    |proj g|=  7.32290D+05
#
# At iterate    4    f=  3.56115D+03    |proj g|=  5.14649D+05
#
# At iterate    5    f=  2.82075D+03    |proj g|=  5.70302D+04
#
# At iterate    6    f=  2.78558D+03    |proj g|=  4.47701D+04
#
# At iterate    7    f=  2.74858D+03    |proj g|=  4.43854D+04
#
# At iterate    8    f=  2.41568D+03    |proj g|=  8.57197D+04
#
# At iterate    9    f=  2.05072D+03    |proj g|=  1.04148D+05
#
# At iterate   10    f=  1.63820D+03    |proj g|=  1.83947D+04
#
# At iterate   11    f=  1.60104D+03    |proj g|=  1.89628D+04
#
# At iterate   12    f=  1.58346D+03    |proj g|=  1.08123D+04
#
# At iterate   13    f=  1.49549D+03    |proj g|=  1.91373D+04
#
# At iterate   14    f=  1.44318D+03    |proj g|=  1.42116D+05
#
# At iterate   15    f=  1.37237D+03    |proj g|=  5.08541D+04
#
# At iterate   16    f=  1.34055D+03    |proj g|=  6.16171D+03
#
# At iterate   17    f=  1.33875D+03    |proj g|=  3.81906D+03
#
# At iterate   18    f=  1.33560D+03    |proj g|=  3.20374D+03
#
# At iterate   19    f=  1.31608D+03    |proj g|=  2.65286D+04
#
# At iterate   20    f=  1.28626D+03    |proj g|=  1.98100D+04
#
# At iterate   21    f=  1.26409D+03    |proj g|=  7.23011D+03
#
# At iterate   22    f=  1.26261D+03    |proj g|=  1.45327D+03
#
# At iterate   23    f=  1.26249D+03    |proj g|=  1.42117D+03
#
# At iterate   24    f=  1.26240D+03    |proj g|=  1.67312D+03
#
# At iterate   25    f=  1.26173D+03    |proj g|=  6.48874D+03
#
# At iterate   26    f=  1.26075D+03    |proj g|=  6.97376D+03
#
# At iterate   27    f=  1.25841D+03    |proj g|=  7.15378D+03
#
# At iterate   28    f=  1.25063D+03    |proj g|=  2.87669D+04
#
# At iterate   29    f=  1.23268D+03    |proj g|=  5.32015D+04
#
# At iterate   30    f=  1.21695D+03    |proj g|=  4.47809D+04
#
# At iterate   31    f=  1.21134D+03    |proj g|=  1.98964D+04
#
# At iterate   32    f=  1.21039D+03    |proj g|=  5.85552D+03
#
# At iterate   33    f=  1.21027D+03    |proj g|=  4.09971D+02
#
# At iterate   34    f=  1.21025D+03    |proj g|=  6.34050D+02
#
# At iterate   35    f=  1.21021D+03    |proj g|=  1.36025D+03
#
# At iterate   36    f=  1.21019D+03    |proj g|=  1.78751D+03
#
# At iterate   37    f=  1.21019D+03    |proj g|=  1.43188D+03
#
# At iterate   38    f=  1.21018D+03    |proj g|=  3.73174D+02
#
# At iterate   39    f=  1.21018D+03    |proj g|=  4.08508D+01
#
# At iterate   40    f=  1.21018D+03    |proj g|=  4.09583D+01
#
# At iterate   41    f=  1.21018D+03    |proj g|=  4.37390D+01
#
# At iterate   42    f=  1.21018D+03    |proj g|=  1.22530D+02
#
# At iterate   43    f=  1.21018D+03    |proj g|=  2.11878D+02
#
# At iterate   44    f=  1.21018D+03    |proj g|=  4.80767D+02
#
# At iterate   45    f=  1.21017D+03    |proj g|=  5.67950D+02
#
# At iterate   46    f=  1.21017D+03    |proj g|=  9.46056D+02
#
# At iterate   47    f=  1.21015D+03    |proj g|=  8.40839D+02
#
# At iterate   48    f=  1.21014D+03    |proj g|=  2.73904D+02
#
# At iterate   49    f=  1.21014D+03    |proj g|=  5.54432D+02
#
# At iterate   50    f=  1.21014D+03    |proj g|=  4.94146D+01
#
# At iterate   51    f=  1.21014D+03    |proj g|=  3.25147D+01
#
# At iterate   52    f=  1.21013D+03    |proj g|=  8.75549D+01
#
# At iterate   53    f=  1.21013D+03    |proj g|=  6.44792D+01
#
# At iterate   54    f=  1.21012D+03    |proj g|=  1.77680D+02
#
# At iterate   55    f=  1.21012D+03    |proj g|=  2.03815D+02
#
# At iterate   56    f=  1.21011D+03    |proj g|=  5.64117D+02
#
# At iterate   57    f=  1.21010D+03    |proj g|=  1.87480D+03
#
# At iterate   58    f=  1.21009D+03    |proj g|=  2.47956D+02
#
# At iterate   59    f=  1.21008D+03    |proj g|=  7.13894D+01
#
# At iterate   60    f=  1.21008D+03    |proj g|=  1.54751D+02
#
# At iterate   61    f=  1.21008D+03    |proj g|=  7.67609D+02
#
# At iterate   62    f=  1.21008D+03    |proj g|=  4.63631D+02
#
# At iterate   63    f=  1.21007D+03    |proj g|=  2.11953D+02
#
# At iterate   64    f=  1.21006D+03    |proj g|=  5.30785D+02
#
# At iterate   65    f=  1.21006D+03    |proj g|=  3.91739D+02
#
# At iterate   66    f=  1.21005D+03    |proj g|=  7.00589D+01
#
# At iterate   67    f=  1.21005D+03    |proj g|=  9.58118D+01
#
# At iterate   68    f=  1.21005D+03    |proj g|=  9.72486D+01
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1210.0512415818753
#         x: [ 1.483e-01 -1.042e-01  5.651e-02 -7.483e-02  3.921e-02
#              7.873e-02 -7.364e-02  3.893e-02  4.300e+02  4.300e+02]
#       nit: 69
#       jac: [-1.280e+02 -1.116e+02 -9.257e+01 -6.382e+01 -4.706e+01
#             -6.999e+00 -6.360e+00 -6.074e+00 -1.826e-02 -8.436e-03]
#      nfev: 880
#      njev: 80
#  hess_inv: <10x10 LbfgsInvHessProduct with dtype=float64>
# At iterate   69    f=  1.21005D+03    |proj g|=  1.27984D+02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     69     80      1     0     0   1.280D+02   1.210D+03
#   F =   1210.0512415818753
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# initial guesses [ 1.0e-01 -5.0e-02  2.0e-02 -1.0e-02  2.0e-02  4.0e-02 -2.0e-02  6.0e-02
#   4.3e+02  4.3e+02]
# MLE value [ 1.48317470e-01 -1.04187257e-01  5.65086745e-02 -7.48305601e-02
#   3.92116483e-02  7.87341165e-02 -7.36367262e-02  3.89273568e-02
#   4.30000016e+02  4.30000013e+02]

# %% [markdown]
# ### MLE Fit

# %%
########### CHANGE HERE #############
### Add the necessary parameter values which are already calibrated along with the current parameters ##############

beta_i[:,0] = param_mle[0] +  param_mle[1]/(1 + np.exp((t1-tmoh)))  \
+ param_mle[2]/(1 + np.exp((t2-tmoh))) \
+ param_mle[3]/(1 + np.exp((t3-tmoh))) \
+ param_mle[4]/(1 + np.exp((t4-tmoh))) \
+ param_mle[5]/(1 + np.exp((t5-tmoh))) \
+ param_mle[6]/(1 + np.exp((t6-tmoh))) \
+ param_mle[7]/(1 + np.exp((t7-tmoh))) \
# + param_mle[8]/(1 + np.exp((t8-tmoh)))


E[0,0] = param_mle[8]

I[0,0] = param_mle[9]

###########################################

beta_e[:,0] = beta_i[:,0]
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


## load saved true infection data

data = np.loadtxt(f'{datapath}/coupled_toronto_synthetic_truth_all.csv',delimiter=",")
I_truth = data[0:len(tmoh),2]

fig1, ax1 = plt.subplots(figsize=(6, 4))
# plt.plot(t[:tlim], I_synthetic[:tlim,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh[:int(tlim*ndiv)], I[:int(tlim*ndiv),0], '-',linewidth=2, label='MLE fit')
plt.plot(tmoh[:int(tlim*ndiv)], I_truth, '-',linewidth=2, label='True model')
# plt.plot(t[:tlim], Data[:tlim,0], '-',linewidth=2, label='True model')
plt.legend(loc='best')
plt.xlabel('Time (days)')
plt.xlim([0,tlim])
plt.ylabel('Infected cases')
plt.grid()
plt.savefig(f'{figpath}/MLE_fit.pdf', bbox_inches='tight')
plt.show()


## load saved true model of beta

file = np.loadtxt(f'{datapath}/coupled_true_beta.csv',delimiter=',')
beta_truth = file[0:len(tmoh),0]


fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Infection rate - MLE fit')
plt.plot(tmoh, beta_truth, label='Infection rate - Truth')
plt.legend(loc='best')
plt.savefig(f'{figpath}/beta_fit.pdf',  bbox_inches='tight')
plt.show()
